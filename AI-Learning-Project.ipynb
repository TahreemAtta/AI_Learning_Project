# %%
# !mkdir AI_Learning_Project
# !cd AI_Learning_Project
# !mkdir datasets notebooks models outputs scripts images docs
# !touch requirements.txt
# !touch notebooks/notes.txt
# !touch models/model.txt
# !touch scripts/train.py
# !touch docs/guide.txt
# !touch README.md

# %%
# !ls -R
# Out:
# .:
# AI_Learning_Project  docs    models	outputs    requirements.txt  scripts
# datasets	     images  notebooks	README.md  sample_data
#
# ./AI_Learning_Project:
#
# ./datasets:
#
# ./docs:
# guide.txt
#
# ./images:
#
# ./models:
# model.txt
#
# ./notebooks:
# notes.txt
#
# ./outputs:
#
# ./sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md
#
# ./scripts:
# train.py

# %%
# !echo "# AI Learning Project" > README.md
# !echo "Student Name: Tahreem Attaullah" >> README.md
# !echo "Roll Number: 04" >> README.md
# !echo "Description: A basic project structure built using Linux commands in Google Colab." >> README.md

# !echo "numpy" > requirements.txt
# !echo "pandas" >> requirements.txt
# !echo "matplotlib" >> requirements.txt

# !echo "This folder structure organizes an AI project." > docs/guide.txt
# !echo "datasets/ contains data, notebooks/ has experimentation, and scripts/ contains executable python files." >> docs/guide.txt

# !echo "ID,Name,Marks" > datasets/students.csv
# !echo "1,Tahreem Attaullah,96" >> datasets/students.csv
# !echo "2,Fatima,90" >> datasets/students.csv
# !echo "3,Musfeera Tanveer,91" >> datasets/students.csv
# !echo "4,Maham Ali,78" >> datasets/students.csv
# !echo "5,Sadaf Naz,60" >> datasets/students.csv
# !echo "6,Sobia Sharif,76" >> datasets/students.csv
# !echo "7,Nimra,74" >> datasets/students.csv
# !echo "8,Umair Iqbal,82" >> datasets/students.csv
# !echo "9,Abdullah Jamil,98" >> datasets/students.csv
# !echo "10,M.Umar,89" >> datasets/students.csv
# !echo "11,Umair Younus,85" >> datasets/students.csv
# !echo "12,Junaid Younus,93" >> datasets/students.csv
# !echo "13,Ali Raza,94" >> datasets/students.csv
# !echo "14,Mehboob Alam,68" >> datasets/students.csv
# !echo "15,Tehmina Younus,83" >> datasets/students.csv

# %%
# !pwd
# !ls

# !cat README.md
# !head datasets/students.csv
# !file datasets/students.csv
# !tail -6 datasets/students.csv
# !cp README.md docs/

# !mv scripts/train.py scripts/

# !rm models/model.txt
# Out:
# /content
# AI_Learning_Project	 docs	 notebooks  requirements.txt
# AI_Learning_Project.zip  images  outputs    sample_data
# datasets		 models  README.md  scripts
# # AI Learning Project
# Student Name: Tahreem Attaullah
# Roll Number: 04
# Description: A basic project structure built using Linux commands in Google Colab.
# ID,Name,Marks
# 1,Tahreem Attaullah,96
# 2,Fatima,90
# 3,Musfeera Tanveer,91
# 4,Maham Ali,78
# 5,Sadaf Naz,60
# 6,Sobia Sharif,76
# 7,Nimra,74
# 8,Umair Iqbal,82
# 9,Abdullah Jamil,98
# datasets/students.csv: CSV text
# 10,M.Umar,89
# 11,Umair Younus,85
# 12,Junaid Younus,93
# 13,Ali Raza,94
# 14,Mehboob Alam,68
# 15,Tehmina Younus,83
# mv: 'scripts/train.py' and 'scripts/train.py' are the same file
# rm: cannot remove 'models/model.txt': No such file or directory

# %%
# !cd ..
# !zip -r AI_Learning_Project.zip AI_Learning_Project
# Out:
#   adding: AI_Learning_Project/ (stored 0%)
